# %% [markdown]
# 参考動画：https://www.youtube.com/watch?v=l9KRgSUeNXk

# %%
#ライブラリのインポート
from time import sleep #Pythonの実行を●秒間停止させる
from bs4 import BeautifulSoup
import requests

# %%
#アクセスするURLを設定する
url = "https://suumo.jp/chintai/tokyo/sc_shinagawa/?page={}"

#変数d_listに空のリストを作成する
d_list = []

#スクレイピングする最大ページ数を設定
max_page = 100

# %%
#1~max_pageをループする
for i in range (1,max_page+1):
    print('d_listの大きさ:',len(d_list))

    #変数target_urlに、アクセス先のURLを格納する
    target_url = url.format(i)

    #print()してtarget_urlを確認する
    print(target_url)

    #Requestsを使って設定したURLにアクセスする
    r = requests.get(target_url)

    #1秒の間隔をあけて実行
    sleep(1)

    #取得したHTMLをBeautifulSoupで解析する
    soup = BeautifulSoup(r.text)

    #すべての物件情報（20件）を取得する
    contents = soup.find_all('div',class_='cassetteitem')

    #各物件情報をforループで取得する
    for content in contents:

        #物件情報と部屋情報を取得しておく
        detail = content.find('div',class_='cassetteitem-detail')
        table = content.find('table',class_='cassetteitem_other')

        #物件情報から必要な情報を取得する
        title = detail.find('div',class_='cassetteitem_content-title').text
        address = detail.find('li',class_='cassetteitem_detail-col1').text
        access1 = detail.find_all('div', class_='cassetteitem_detail-text')[0].text
        access2 = detail.find_all('div', class_='cassetteitem_detail-text')[1].text
        access3 = detail.find_all('div', class_='cassetteitem_detail-text')[2].text
        age = detail.find('li', class_='cassetteitem_detail-col3').find_all('div')[0].text
        height = detail.find('li', class_='cassetteitem_detail-col3').find_all('div')[1].text

        #部屋情報のブロックから、各部屋を取得する
        tr_tags = table.find_all('tr',class_='js-cassette_link')

        #各部屋情報をforループで取得する
        for tr_tag in tr_tags:

            #部屋情報の行から、欲しい情報を取得する
            floor,price,first_fee,capacity = tr_tag.find_all('td')[2:6]

            #さらに細かい情報を取得する
            fee,management_fee = price.find_all('li')
            deposit,gratuity = first_fee.find_all('li')
            madori,menseki =capacity.find_all('li')

            #取得したすべての情報を辞書に格納する
            d = {
                'title':title,
                'address':address,
                'access1':access1,
                'access2':access2,
                'access3':access3,
                'age':age,
                'height':height,
                'floor':floor.text,
                'fee':fee.text,
                'management_fee':management_fee.text,
                'deposit':deposit.text,
                'gratuity':gratuity.text,
                'madori':madori.text,
                'menseki':menseki.text,
            }

            d_list.append(d)
# Out:
# d_listの大きさ: 0
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=1
# d_listの大きさ: 102
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=2
# d_listの大きさ: 164
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=3
# d_listの大きさ: 245
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=4
# d_listの大きさ: 358
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=5
# d_listの大きさ: 490
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=6
# d_listの大きさ: 531
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=7
# d_listの大きさ: 591
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=8
# d_listの大きさ: 631
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=9
# d_listの大きさ: 676
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=10
# d_listの大きさ: 723
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=11
# d_listの大きさ: 1478
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=12
# d_listの大きさ: 1655
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=13
# d_listの大きさ: 1908
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=14
# d_listの大きさ: 2012
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=15
# d_listの大きさ: 2079
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=16
# d_listの大きさ: 2270
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=17
# d_listの大きさ: 2339
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=18
# d_listの大きさ: 2412
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=19
# d_listの大きさ: 2487
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=20
# d_listの大きさ: 2640
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=21
# d_listの大きさ: 2727
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=22
# d_listの大きさ: 2786
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=23
# d_listの大きさ: 2917
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=24
# d_listの大きさ: 3039
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=25
# d_listの大きさ: 3119
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=26
# d_listの大きさ: 3284
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=27
# d_listの大きさ: 3351
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=28
# d_listの大きさ: 3399
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=29
# d_listの大きさ: 3467
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=30
# d_listの大きさ: 3548
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=31
# d_listの大きさ: 3623
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=32
# d_listの大きさ: 3662
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=33
# d_listの大きさ: 3722
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=34
# d_listの大きさ: 3797
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=35
# d_listの大きさ: 3851
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=36
# d_listの大きさ: 3922
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=37
# d_listの大きさ: 4042
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=38
# d_listの大きさ: 4142
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=39
# d_listの大きさ: 4186
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=40
# d_listの大きさ: 4252
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=41
# d_listの大きさ: 4324
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=42
# d_listの大きさ: 4380
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=43
# d_listの大きさ: 4423
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=44
# d_listの大きさ: 4471
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=45
# d_listの大きさ: 4508
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=46
# d_listの大きさ: 4594
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=47
# d_listの大きさ: 4667
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=48
# d_listの大きさ: 4733
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=49
# d_listの大きさ: 4775
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=50
# d_listの大きさ: 4819
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=51
# d_listの大きさ: 4861
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=52
# d_listの大きさ: 4915
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=53
# d_listの大きさ: 4955
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=54
# d_listの大きさ: 5008
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=55
# d_listの大きさ: 5053
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=56
# d_listの大きさ: 5097
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=57
# d_listの大きさ: 5141
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=58
# d_listの大きさ: 5188
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=59
# d_listの大きさ: 5247
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=60
# d_listの大きさ: 5303
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=61
# d_listの大きさ: 5352
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=62
# d_listの大きさ: 5390
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=63
# d_listの大きさ: 5437
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=64
# d_listの大きさ: 5490
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=65
# d_listの大きさ: 5566
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=66
# d_listの大きさ: 5640
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=67
# d_listの大きさ: 5692
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=68
# d_listの大きさ: 5739
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=69
# d_listの大きさ: 5772
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=70
# d_listの大きさ: 5836
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=71
# d_listの大きさ: 5890
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=72
# d_listの大きさ: 5942
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=73
# d_listの大きさ: 5983
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=74
# d_listの大きさ: 6040
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=75
# d_listの大きさ: 6073
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=76
# d_listの大きさ: 6137
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=77
# d_listの大きさ: 6240
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=78
# d_listの大きさ: 6302
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=79
# d_listの大きさ: 6344
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=80
# d_listの大きさ: 6418
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=81
# d_listの大きさ: 6459
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=82
# d_listの大きさ: 6503
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=83
# d_listの大きさ: 6538
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=84
# d_listの大きさ: 6568
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=85
# d_listの大きさ: 6611
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=86
# d_listの大きさ: 6653
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=87
# d_listの大きさ: 6693
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=88
# d_listの大きさ: 6741
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=89
# d_listの大きさ: 6790
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=90
# d_listの大きさ: 6824
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=91
# d_listの大きさ: 6874
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=92
# d_listの大きさ: 6905
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=93
# d_listの大きさ: 6948
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=94
# d_listの大きさ: 6981
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=95
# d_listの大きさ: 7028
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=96
# d_listの大きさ: 7061
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=97
# d_listの大きさ: 7092
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=98
# d_listの大きさ: 7214
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=99
# d_listの大きさ: 7287
# https://suumo.jp/chintai/tokyo/sc_shinagawa/?page=100

# %%
#CSVを作成するためpandasをインポート
import pandas as pd
import re

# %%
#d_listの2番目まで中身を確認してみる
d_list[:2]
# Out:
# [{'title': '季美 東大井',
#   'address': '東京都品川区東大井２',
#   'access1': '京急本線/立会川駅 歩7分',
#   'access2': '京急本線/鮫洲駅 歩8分',
#   'access3': '東急大井町線/大井町駅 歩12分',
#   'age': '築10年',
#   'height': '14階建',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t10階',
#   'fee': '17.2万円',
#   'management_fee': '10000円',
#   'deposit': '17.2万円',
#   'gratuity': '17.2万円',
#   'madori': '2LDK',
#   'menseki': '68.41m2'},
#  {'title': 'グランドメゾン品川シーサイドの杜',
#   'address': '東京都品川区東品川４',
#   'access1': 'りんかい線/品川シーサイド駅 歩3分',
#   'access2': '京急本線/青物横丁駅 歩6分',
#   'access3': 'ＪＲ京浜東北線/大井町駅 歩16分',
#   'age': '築5年',
#   'height': '19階建',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t11階',
#   'fee': '28.5万円',
#   'management_fee': '-',
#   'deposit': '57万円',
#   'gratuity': '28.5万円',
#   'madori': '3LDK',
#   'menseki': '72.27m2'}]

# %%
#変数d_listを使って、データフレームを作成する
df =pd.DataFrame(d_list)

# %%
df.head()
# Out:
#               title     address             access1            access2  \
# 0            季美 東大井  東京都品川区東大井２       京急本線/立会川駅 歩7分       京急本線/鮫洲駅 歩8分
# 1  グランドメゾン品川シーサイドの杜  東京都品川区東品川４  りんかい線/品川シーサイド駅 歩3分     京急本線/青物横丁駅 歩6分
# 2  グランドメゾン品川シーサイドの杜  東京都品川区東品川４  りんかい線/品川シーサイド駅 歩3分     京急本線/青物横丁駅 歩6分
# 3      WAHRF大井町west   東京都品川区二葉２     ＪＲ横須賀線/西大井駅 歩7分  ＪＲ京浜東北線/大井町駅 歩18分
# 4      WAHRF大井町west   東京都品川区二葉２     ＪＲ横須賀線/西大井駅 歩7分  ＪＲ京浜東北線/大井町駅 歩18分
#
#              access3   age height                          floor     fee  \
# 0   東急大井町線/大井町駅 歩12分  築10年   14階建  \r\n\t\t\t\t\t\t\t\t\t\t\t10階  17.2万円
# 1  ＪＲ京浜東北線/大井町駅 歩16分   築5年   19階建  \r\n\t\t\t\t\t\t\t\t\t\t\t11階  28.5万円
# 2  ＪＲ京浜東北線/大井町駅 歩16分   築5年   19階建   \r\n\t\t\t\t\t\t\t\t\t\t\t8階    32万円
# 3    東急大井町線/下神明駅 歩7分    新築    4階建   \r\n\t\t\t\t\t\t\t\t\t\t\t2階  10.4万円
# 4    東急大井町線/下神明駅 歩7分    新築    4階建   \r\n\t\t\t\t\t\t\t\t\t\t\t2階  10.6万円
#
#   management_fee deposit gratuity madori  menseki
# 0         10000円  17.2万円   17.2万円   2LDK  68.41m2
# 1              -    57万円   28.5万円   3LDK  72.27m2
# 2              -    64万円     32万円   3LDK  71.68m2
# 3         15000円       -        -    1DK   25.3m2
# 4         15000円       -        -    1DK  25.04m2

# %%
#access列を分割し、余分な文字は削除し、数値に変換
df[['access1_route', 'access1_station', 'access1_time']] = df['access1'].str.extract(r'([^/]+)/(.*?) 歩(\d+)分')
df[['access2_route', 'access2_station', 'access2_time']] = df['access2'].str.extract(r'([^/]+)/(.*?) 歩(\d+)分')
df[['access3_route', 'access3_station', 'access3_time']] = df['access3'].str.extract(r'([^/]+)/(.*?) 歩(\d+)分')

# 不要になったaccess列を削除
df.drop(['access1','access2','access3'], axis=1, inplace=True)

#age列の処理：”築●年”を削除し、数値に変換
def convert_age(age_data):
    if '新築' in age_data:
        return 0
    else:
        return int(age_data.replace('築', '').replace('年', ''))
df['age'] = df['age'].apply(convert_age)

#height列の処理："階建"を削除し、数値に変換
df['height'] = pd.to_numeric(df['height'].str.rstrip('階建'),errors='coerce').fillna(0)

#floor列の処理："階"を削除し、数値に変換
df['floor'] = pd.to_numeric(df['floor'].str.rstrip('階'),errors='coerce').fillna(0)

#fee列の処理："万円"を削除し、数値に変換
df['fee'] = pd.to_numeric(df['fee'].str.rstrip('万円'),errors='coerce').fillna(0)

#management_fee列の処理："円"を削除し、数値に変換
df['management_fee'] = pd.to_numeric(df['management_fee'].str.rstrip('円'),errors='coerce').fillna(0)

# deposit列の処理: "万円" を削除し、数値に変換
df['deposit'] = pd.to_numeric(df['deposit'].str.rstrip('万円'), errors='coerce').fillna(0)

#gratuity列の処理："万円"を削除し、数値に変換
df['gratuity'] = pd.to_numeric(df['gratuity'].str.rstrip('万円'), errors='coerce').fillna(0)

#menseki列の処理："m2"を削除し、数値に変換
df['menseki'] = pd.to_numeric(df['menseki'].str.rstrip('m2'), errors='coerce').fillna(0)

# %%
df
# Out:
#                  title     address  age  height  floor   fee  management_fee  \
# 0               季美 東大井  東京都品川区東大井２   10    14.0   10.0  17.2         10000.0
# 1     グランドメゾン品川シーサイドの杜  東京都品川区東品川４    5    19.0   11.0  28.5             0.0
# 2     グランドメゾン品川シーサイドの杜  東京都品川区東品川４    5    19.0    8.0  32.0             0.0
# 3         WAHRF大井町west   東京都品川区二葉２    0     4.0    2.0  10.4         15000.0
# 4         WAHRF大井町west   東京都品川区二葉２    0     4.0    2.0  10.6         15000.0
# ...                ...         ...  ...     ...    ...   ...             ...
# 7320          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    5.0  12.0         10000.0
# 7321          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    6.0  13.2         10000.0
# 7322          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    6.0  13.2         13000.0
# 7323             ＴＭ東品川  東京都品川区東品川１   37     4.0    3.0  12.0             0.0
# 7324             ＴＭ東品川  東京都品川区東品川１   37     4.0    3.0  12.5             0.0
#
#       deposit  gratuity madori  menseki access1_route access1_station  \
# 0        17.2      17.2   2LDK    68.41          京急本線            立会川駅
# 1        57.0      28.5   3LDK    72.27         りんかい線        品川シーサイド駅
# 2        64.0      32.0   3LDK    71.68         りんかい線        品川シーサイド駅
# 3         0.0       0.0    1DK    25.30        ＪＲ横須賀線            西大井駅
# 4         0.0       0.0    1DK    25.04        ＪＲ横須賀線            西大井駅
# ...       ...       ...    ...      ...           ...             ...
# 7320     24.0      12.0     1K    30.00         ＪＲ山手線             品川駅
# 7321     26.4      13.2     1K    35.10         ＪＲ山手線             品川駅
# 7322     13.2      13.2     1K    35.10         ＪＲ山手線             品川駅
# 7323     12.0      12.0    2DK    32.07         りんかい線         天王洲アイル駅
# 7324     12.5      12.5    2DK    32.00         りんかい線         天王洲アイル駅
#
#      access1_time access2_route access2_station access2_time access3_route  \
# 0               7          京急本線             鮫洲駅            8        東急大井町線
# 1               3          京急本線           青物横丁駅            6       ＪＲ京浜東北線
# 2               3          京急本線           青物横丁駅            6       ＪＲ京浜東北線
# 3               7       ＪＲ京浜東北線            大井町駅           18        東急大井町線
# 4               7       ＪＲ京浜東北線            大井町駅           18        東急大井町線
# ...           ...           ...             ...          ...           ...
# 7320           12         ＪＲ山手線            五反田駅           14          京急本線
# 7321           12         ＪＲ山手線            五反田駅           14          京急本線
# 7322           12         ＪＲ山手線            五反田駅           14          京急本線
# 7323            8          京急本線            北品川駅           10       ＪＲ京浜東北線
# 7324            8          京急本線            北品川駅           10       ＪＲ京浜東北線
#
#      access3_station access3_time
# 0               大井町駅           12
# 1               大井町駅           16
# 2               大井町駅           16
# 3               下神明駅            7
# 4               下神明駅            7
# ...              ...          ...
# 7320            北品川駅            8
# 7321            北品川駅            8
# 7322            北品川駅            8
# 7323             品川駅           19
# 7324             品川駅           19
#
# [7325 rows x 20 columns]

# %%
#完全一致する重複した行を数える
df.duplicated().sum()
# Out:
# 921

# %%
#指定した項目が一致する行を数える
df.duplicated(subset=['address','age','height','floor','fee','madori','menseki']).sum()
# Out:
# 2972

# %%
#指定した項目が一致した重複業を削除する
df.drop_duplicates(subset=['address','age','height','floor','fee','madori','menseki'],inplace=True)

# %%
df
# Out:
#                  title     address  age  height  floor   fee  management_fee  \
# 0               季美 東大井  東京都品川区東大井２   10    14.0   10.0  17.2         10000.0
# 1     グランドメゾン品川シーサイドの杜  東京都品川区東品川４    5    19.0   11.0  28.5             0.0
# 2     グランドメゾン品川シーサイドの杜  東京都品川区東品川４    5    19.0    8.0  32.0             0.0
# 3         WAHRF大井町west   東京都品川区二葉２    0     4.0    2.0  10.4         15000.0
# 4         WAHRF大井町west   東京都品川区二葉２    0     4.0    2.0  10.6         15000.0
# ...                ...         ...  ...     ...    ...   ...             ...
# 7319          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    8.0  11.2         10000.0
# 7320          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    5.0  12.0         10000.0
# 7321          ヒルサイド御殿山  東京都品川区北品川４   20     9.0    6.0  13.2         10000.0
# 7323             ＴＭ東品川  東京都品川区東品川１   37     4.0    3.0  12.0             0.0
# 7324             ＴＭ東品川  東京都品川区東品川１   37     4.0    3.0  12.5             0.0
#
#       deposit  gratuity madori  menseki access1_route access1_station  \
# 0        17.2      17.2   2LDK    68.41          京急本線            立会川駅
# 1        57.0      28.5   3LDK    72.27         りんかい線        品川シーサイド駅
# 2        64.0      32.0   3LDK    71.68         りんかい線        品川シーサイド駅
# 3         0.0       0.0    1DK    25.30        ＪＲ横須賀線            西大井駅
# 4         0.0       0.0    1DK    25.04        ＪＲ横須賀線            西大井駅
# ...       ...       ...    ...      ...           ...             ...
# 7319     22.4      11.2     1K    27.27         ＪＲ山手線             品川駅
# 7320     24.0      12.0     1K    30.00         ＪＲ山手線             品川駅
# 7321     26.4      13.2     1K    35.10         ＪＲ山手線             品川駅
# 7323     12.0      12.0    2DK    32.07         りんかい線         天王洲アイル駅
# 7324     12.5      12.5    2DK    32.00         りんかい線         天王洲アイル駅
#
#      access1_time access2_route access2_station access2_time access3_route  \
# 0               7          京急本線             鮫洲駅            8        東急大井町線
# 1               3          京急本線           青物横丁駅            6       ＪＲ京浜東北線
# 2               3          京急本線           青物横丁駅            6       ＪＲ京浜東北線
# 3               7       ＪＲ京浜東北線            大井町駅           18        東急大井町線
# 4               7       ＪＲ京浜東北線            大井町駅           18        東急大井町線
# ...           ...           ...             ...          ...           ...
# 7319           12         ＪＲ山手線            五反田駅           14          京急本線
# 7320           12         ＪＲ山手線            五反田駅           14          京急本線
# 7321           12         ＪＲ山手線            五反田駅           14          京急本線
# 7323            8          京急本線            北品川駅           10       ＪＲ京浜東北線
# 7324            8          京急本線            北品川駅           10       ＪＲ京浜東北線
#
#      access3_station access3_time
# 0               大井町駅           12
# 1               大井町駅           16
# 2               大井町駅           16
# 3               下神明駅            7
# 4               下神明駅            7
# ...              ...          ...
# 7319            北品川駅            8
# 7320            北品川駅            8
# 7321            北品川駅            8
# 7323             品川駅           19
# 7324             品川駅           19
#
# [4353 rows x 20 columns]

# %% [markdown]
# Pythonからスプレッドシートに格納
# 参考サイト：https://tanuhack.com/operate-spreadsheet/

# %%
# !pip install gspread #Python3.X系でもスプレッドシートを操作できるライブラリ
# !pip install oauth2client #Googleの各種APIへアクセスできるようにするライブラリ
# Out:
# ERROR: Invalid requirement: '#Python3.X系でもスプレッドシートを操作できるライブラリ'
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#Googleの各種APIへアクセスできるようにするライブラリ'
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gspread
import json

#ServiceAccountCredentials：Googleの各サービスへアクセスできるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials

# 認証のためのAPIキーを含むjsonファイル
google_spreadsheet_api = 'r-suzuki@step3-suumo.iam.gserviceaccount.com'

#2つのAPIを記述しないとリフレッシュトークンを3600秒毎に発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

#ダウンロードしたjsonファイル名をクレデンシャル変数に設定（秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name('google_spreadsheet_api', scope)

#OAuth2の資格情報を使用してGoogle APIにログインします。
gs = gspread.authorize(credentials)

#共有設定したスプレッドシートキーを変数[SPREADSHEET_KEY]に格納する。
SPREADSHEET_KEY = 'r-suzuki@step3-suumo.iam.gserviceaccount.com'
workbook = gs.open_by_key(SPREADSHEET_KEY)
worksheet = workbook.worksheet('Step3_SUUMO')

# 対象のシートにdfのデータを記入。但しindexは除く。
set_with_dataframe(worksheet, df, include_index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\ryusu\OneDrive\ドキュメント\Tech0\STEP3\SUUMO.ipynb セル 17 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/ryusu/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Tech0/STEP3/SUUMO.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
#      <a href='vscode-notebook-cell:/c%3A/Users/ryusu/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Tech0/STEP3/SUUMO.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> #ダウンロードしたjsonファイル名をクレデンシャル変数に設定（秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ryusu/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Tech0/STEP3/SUUMO.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> credentials = ServiceAccountCredentials.from_json_keyfile_name('google_spreadsheet_api', scope)
#      <a href='vscode-notebook-cell:/c%3A/Users/ryusu/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Tech0/STEP3/SUUMO.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> #OAuth2の資格情報を使用してGoogle APIにログインします。
#      <a href='vscode-notebook-cell:/c%3A/Users/ryusu/OneDrive/%E3%83%89%E3%82%AD%E3%83%A5%E3%83%A1%E3%83%B3%E3%83%88/Tech0/STEP3/SUUMO.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a> gs = gspread.authorize(credentials)
#
# File c:\Users\ryusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\oauth2client\service_account.py:219, in ServiceAccountCredentials.from_json_keyfile_name(cls, filename, scopes, token_uri, revoke_uri)
#     193 @classmethod
#     194 def from_json_keyfile_name(cls, filename, scopes='',
#     195                            token_uri=None, revoke_uri=None):
#     197     """Factory constructor from JSON keyfile by name.
#     198
#     199     Args:
#    (...)
#     217             the keyfile.
#     218     """
# --> 219     with open(filename, 'r') as file_obj:
#     220         client_credentials = json.load(file_obj)
#     221     return cls._from_parsed_json_keyfile(client_credentials, scopes,
#     222                                          token_uri=token_uri,
#     223                                          revoke_uri=revoke_uri)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'google_spreadsheet_api'
